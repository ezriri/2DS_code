# %%
from glob import glob
import os
import numpy as np
import pandas as pd

# %% [markdown]
# ## combine csv stats together
# (i actually used my basic csv folder to run this)

# %%
base_path = '/gws/nopw/j04/dcmex/users/ezriab/processed_stats/hvps/particle_stats/'

if os.path.exists(base_path):
    # get string of full path + filenames in specif location
    file_list = glob(base_path+'*.csv') 
    
    # just get file names
    file_names = [os.path.basename(file_path) for file_path in file_list]

# %%
file_names
# Out:
# ['220719154335_envi_stats.csv',
#  '220720161816_envi_stats.csv',
#  '220722154636_envi_stats.csv',
#  '220723153143_envi_stats.csv',
#  '220725153247_envi_stats.csv',
#  '220726150407_envi_stats.csv',
#  '220727154134_envi_stats.csv',
#  '220729153134_envi_stats.csv',
#  '220730152928_envi_stats.csv',
#  '220731153602_envi_stats.csv',
#  '220731191311_envi_stats.csv',
#  '220801154748_envi_stats.csv',
#  '220802153631_envi_stats.csv',
#  '220802183308_envi_stats.csv',
#  '220803153112_envi_stats.csv',
#  '220804160843_envi_stats.csv',
#  '220806151603_envi_stats.csv',
#  '220806172011_envi_stats.csv',
#  '220807160510_envi_stats.csv',
#  '220807180149_envi_stats.csv',
#  '220808160200_envi_stats.csv',
#  'all_hvps.csv']

# %%
# List to store dataframes
dataframes = []

# Read each CSV file and append it to the list
for file in file_list:
    df = pd.read_csv(file)
    dataframes.append(df)

# Combine all dataframes into one
combined_df = pd.concat(dataframes, ignore_index=True)
# Out:
# /tmp/ipykernel_13345/672142499.py:10: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df
# Out:
#                 name    date slice_s_idx slice_e_idx          start_time  \
# 0          65_19hvps  220719          65          82  18:07:55.174000000
# 1          90_19hvps  220719          90         110  18:10:05.177000000
# 2         173_19hvps  220719         173         184  18:26:39.167000000
# 3         185_19hvps  220719         185         194  18:26:39.167000000
# 4         202_19hvps  220719         202         210  18:26:39.167000000
# ...              ...     ...         ...         ...                 ...
# 78383  563438_08hvps  220808      563438      563781  18:55:46.547000000
# 78384  566925_08hvps  220808      566925      567924  18:55:49.750000000
# 78385  571832_08hvps  220808      571832      572836  18:55:52.350000000
# 78386  591180_08hvps  220808      591180      592179  18:55:55.449000000
# 78387  598900_08hvps  220808      598900      599899  18:55:56.149000000
#
#                  end_time  ellipse_d_max  Euclidean_d_max    Feret_d_max  \
# ...

# %% [markdown]
# ## any duplicates ?
# the output below no longer exists, as i have deleted the files

# %% [markdown]
# ### old version (these files don't exist)

# %%
all_hvps_path = base_path = '/gws/nopw/j04/dcmex/users/ezriab/processed_stats/hvps/particle_stats/all_hvps.csv'
all_df = pd.read_csv(all_hvps_path)
all_df
# Out:
#                 name    date  slice_s_idx  slice_e_idx          start_time  \
# 0          65_19hvps  220719           65           82  18:07:55.174000000
# 1          90_19hvps  220719           90          110  18:10:05.177000000
# 2         173_19hvps  220719          173          184  18:26:39.167000000
# 3         185_19hvps  220719          185          194  18:26:39.167000000
# 4         202_19hvps  220719          202          210  18:26:39.167000000
# ...              ...     ...          ...          ...                 ...
# 78383  563438_08hvps  220808       563438       563781  18:55:46.547000000
# 78384  566925_08hvps  220808       566925       567924  18:55:49.750000000
# 78385  571832_08hvps  220808       571832       572836  18:55:52.350000000
# 78386  591180_08hvps  220808       591180       592179  18:55:55.449000000
# 78387  598900_08hvps  220808       598900       599899  18:55:56.149000000
#
# ...

# %%
duplicates_mask = all_df.duplicated(subset=['name'], keep=False)
all_hvps_duplicates = all_df[duplicates_mask]
all_hvps_duplicates
# Out:
#                  name    date  slice_s_idx  slice_e_idx          start_time  \
# 1399    290886_19hvps  220719       290886       290892  18:53:39.810000000
# 1400    290886_19hvps  220719       290886       290893  18:53:39.810000000
# 6333   1443801_19hvps  220719      1443801      1443811  19:11:25.543000000
# 6334   1443801_19hvps  220719      1443801      1443809  19:11:25.543000000
# 9515   2619336_19hvps  220719      2619336      2619343  19:24:57.573000000
# ...               ...     ...          ...          ...                 ...
# 65775  2070594_31hvps  220731      2070594      2070598  19:43:21.001000000
# 68405    64875_02hvps  220802        64875        64888  19:01:44.785000000
# 68406    64875_02hvps  220802        64875        64890  19:01:44.785000000
# 75803    27309_07hvps  220807        27309        27315  16:05:39.730000000
# 77801    27309_07hvps  220807        27309        27353  18:04:19.397000000
#
# ...

# %% [markdown]
# i have duplicates again. i think i will run the extracting code again, i really can't be arsed.

# %% [markdown]
# ### new files
# how has this happened?? still duplicates

# %%
all_hvps_path = base_path = '/gws/nopw/j04/dcmex/users/ezriab/processed_stats/hvps/particle_stats/all_hvps.csv'
all_df = pd.read_csv(all_hvps_path)
duplicates_mask = all_df.duplicated(subset=['name'], keep=False)
all_hvps_duplicates = all_df[duplicates_mask]
all_hvps_duplicates.sort_values(by=['name'])
# Out:
#                   name    date  slice_s_idx  slice_e_idx          start_time  \
# 36475  164587_1_31hvps  220731       164587       164838  18:28:44.470000000
# 38925  164587_1_31hvps  220731       164587       164595  19:23:25.458000000
# 36523  171592_1_31hvps  220731       171592       171607  18:28:47.768000000
# 39131  171592_1_31hvps  220731       171592       171615  19:23:30.158000000
# 36752  197765_2_31hvps  220731       197765       197772  18:34:40.683000000
# 39379  197765_2_31hvps  220731       197765       197768  19:37:59.189000000
# 36948  211687_1_31hvps  220731       211687       211695  18:34:41.833000000
# 39726  211687_1_31hvps  220731       211687       211697  19:38:00.388000000
# 36959  212189_1_31hvps  220731       212189       212197  18:34:41.833000000
# 39744  212189_1_31hvps  220731       212189       212193  19:38:00.388000000
# 37063  216845_1_31hvps  220731       216845       216855  18:34:42.133000000
# ...

# %%
## basically need to loop through the csv, + on _1 or _2 to column, then add this onto the respective images.
# need to add this onto the inital script for processing.
